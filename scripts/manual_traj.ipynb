# %% [markdown]
# # Trajectories for Cl vacancy compensated

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if '1 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
        
# Create figure:
fig = plt.figure(figsize=(20,20))
fig.tight_layout()
fig.suptitle('Na migration trajectories with 0.27% vacancy concentration \n for undoped', fontsize=25, x=0.5, y=0.68) 
(ax, ax2, ax3) = fig.subplots(1, 3)

ax.set_title('xy projection', size=20)
ax.set_xlabel('x', size=20)
ax.set_ylabel('y', size=20)
ax.set_xlim(-1, 23.505)
ax.set_ylim(-1, 23.505)
ax.set_aspect('equal', adjustable='box')

ax2.set_title('xz projection', size=20)
ax2.set_xlabel('x', size=20)
ax2.set_ylabel('z', size=20)
ax2.set_xlim(-1, 23.505)
ax2.set_ylim(-1, 23.505)
ax2.set_aspect('equal', adjustable='box')

ax3.set_title('yz projection', size=20)
ax3.set_xlabel('y', size=20)
ax3.set_ylabel('z', size=20)
ax3.set_xlim(-1, 23.505)
ax3.set_ylim(-1, 23.505)
ax3.set_aspect('equal', adjustable='box')

# Plot paths:
for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax2.plot(na_coords_x[n], na_coords_z[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax3.plot(na_coords_y[n], na_coords_z[n], color='orange', zorder=-1)

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []
o_coords2 = []
o_coords3 = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
        o_coords2.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
        o_coords3.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p, q, r in zip(o_coords, o_coords2, o_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []
cl_coords2 = []
cl_coords3 = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords2.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords3.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))

del cl_coords[0]
del cl_coords2[0]
del cl_coords3[0]
    
for p, q, r in zip(cl_coords, cl_coords2, cl_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4)]

fig.legend(custom_lines, ['Na', 'O', 'Cl'], loc='upper right', bbox_to_anchor=(0.905,0.68))

# Save figure:
fig.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/schottky_traj.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Trajectories for Mg dopant compensated

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_mg.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_mg.txt') as file:
    content = file.readlines()
for line in content:
    if '2 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
        
# Create figure:
fig = plt.figure(figsize=(20,20))
fig.tight_layout()
fig.suptitle('Na migration trajectories with 0.27% vacancy concentration \n with Mg doping', fontsize=25, x=0.5, y=0.68) 
(ax, ax2, ax3) = fig.subplots(1, 3)

ax.set_title('xy projection', size=20)
ax.set_xlabel('x', size=20)
ax.set_ylabel('y', size=20)
ax.set_xlim(-1, 23.505)
ax.set_ylim(-1, 23.505)
ax.set_aspect('equal', adjustable='box')

ax2.set_title('xz projection', size=20)
ax2.set_xlabel('x', size=20)
ax2.set_ylabel('z', size=20)
ax2.set_xlim(-1, 23.505)
ax2.set_ylim(-1, 23.505)
ax2.set_aspect('equal', adjustable='box')

ax3.set_title('yz projection', size=20)
ax3.set_xlabel('y', size=20)
ax3.set_ylabel('z', size=20)
ax3.set_xlim(-1, 23.505)
ax3.set_ylim(-1, 23.505)
ax3.set_aspect('equal', adjustable='box')

# Plot paths:
for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax2.plot(na_coords_x[n], na_coords_z[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax3.plot(na_coords_y[n], na_coords_z[n], color='orange', zorder=-1)

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []
o_coords2 = []
o_coords3 = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
        o_coords2.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
        o_coords3.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p, q, r in zip(o_coords, o_coords2, o_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []
cl_coords2 = []
cl_coords3 = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords2.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords3.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p, q, r in zip(cl_coords, cl_coords2, cl_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add alkaline earth ion:
mg = [2.250500045010, 2.250500045010, 0]

xy = patches.Circle((mg[0], mg[1]), 0.5, facecolor='pink', edgecolor='black')
xz = patches.Circle((mg[0], mg[2]), 0.5, facecolor='pink', edgecolor='black')
yz = patches.Circle((mg[1], mg[2]), 0.5, facecolor='pink', edgecolor='black')

ax.add_patch(xy)
ax2.add_patch(xz)
ax3.add_patch(yz)

# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='pink', lw=4)]

fig.legend(custom_lines, ['Na', 'O', 'Cl', 'Mg'], loc='upper right', bbox_to_anchor=(0.905,0.68))

# Save figure:
fig.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/mg_traj.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# # Trajectories for Ca dopant compensated

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_ca.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_ca.txt') as file:
    content = file.readlines()
for line in content:
    if '2 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
        
# Create figure:
fig = plt.figure(figsize=(20,20))
fig.tight_layout()
fig.suptitle('Na migration trajectories with 0.27% vacancy concentration \n with Ca doping', fontsize=25, x=0.5, y=0.68) 
(ax, ax2, ax3) = fig.subplots(1, 3)

ax.set_title('xy projection', size=20)
ax.set_xlabel('x', size=20)
ax.set_ylabel('y', size=20)
ax.set_xlim(-1, 23.505)
ax.set_ylim(-1, 23.505)
ax.set_aspect('equal', adjustable='box')

ax2.set_title('xz projection', size=20)
ax2.set_xlabel('x', size=20)
ax2.set_ylabel('z', size=20)
ax2.set_xlim(-1, 23.505)
ax2.set_ylim(-1, 23.505)
ax2.set_aspect('equal', adjustable='box')

ax3.set_title('yz projection', size=20)
ax3.set_xlabel('y', size=20)
ax3.set_ylabel('z', size=20)
ax3.set_xlim(-1, 23.505)
ax3.set_ylim(-1, 23.505)
ax3.set_aspect('equal', adjustable='box')

# Plot paths:
for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax2.plot(na_coords_x[n], na_coords_z[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax3.plot(na_coords_y[n], na_coords_z[n], color='orange', zorder=-1)

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []
o_coords2 = []
o_coords3 = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
        o_coords2.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
        o_coords3.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p, q, r in zip(o_coords, o_coords2, o_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []
cl_coords2 = []
cl_coords3 = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords2.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords3.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p, q, r in zip(cl_coords, cl_coords2, cl_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add alkaline earth ion:
mg = [2.250500045010, 2.250500045010, 0]

xy = patches.Circle((mg[0], mg[1]), 0.5, facecolor='purple', edgecolor='black')
xz = patches.Circle((mg[0], mg[2]), 0.5, facecolor='purple', edgecolor='black')
yz = patches.Circle((mg[1], mg[2]), 0.5, facecolor='purple', edgecolor='black')

ax.add_patch(xy)
ax2.add_patch(xz)
ax3.add_patch(yz)

# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='purple', lw=4)]

fig.legend(custom_lines, ['Na', 'O', 'Cl', 'Ca'], loc='upper right', bbox_to_anchor=(0.905,0.68))

# Save figure:
fig.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/ca_traj.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if '1 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
        
# Create figure:
fig = plt.figure(figsize=(20,20))
fig.tight_layout()
fig.suptitle('Na migration trajectories with 0.27% vacancy concentration \n for undoped', fontsize=25, x=0.5, y=0.68) 
(ax, ax2, ax3) = fig.subplots(1, 3)

ax.set_title('xy projection', size=20)
ax.set_xlabel('x', size=20)
ax.set_ylabel('y', size=20)
ax.set_xlim(-1, 23.505)
ax.set_ylim(-1, 23.505)
ax.set_aspect('equal', adjustable='box')

ax2.set_title('xz projection', size=20)
ax2.set_xlabel('x', size=20)
ax2.set_ylabel('z', size=20)
ax2.set_xlim(-1, 23.505)
ax2.set_ylim(-1, 23.505)
ax2.set_aspect('equal', adjustable='box')

ax3.set_title('yz projection', size=20)
ax3.set_xlabel('y', size=20)
ax3.set_ylabel('z', size=20)
ax3.set_xlim(-1, 23.505)
ax3.set_ylim(-1, 23.505)
ax3.set_aspect('equal', adjustable='box')

# Plot paths:
for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax2.plot(na_coords_x[n], na_coords_z[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax3.plot(na_coords_y[n], na_coords_z[n], color='orange', zorder=-1)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []
cl_coords2 = []
cl_coords3 = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords2.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords3.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))

del cl_coords[0]
del cl_coords2[0]
del cl_coords3[0]
    
for p, q, r in zip(cl_coords, cl_coords2, cl_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='green', lw=4)]

fig.legend(custom_lines, ['Na', 'Cl'], loc='upper right', bbox_to_anchor=(0.905,0.68))

# Save figure:
fig.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/schottky_traj_clear.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_mg.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_mg.txt') as file:
    content = file.readlines()
for line in content:
    if '2 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
        
# Create figure:
fig = plt.figure(figsize=(20,20))
fig.tight_layout()
fig.suptitle('Na migration trajectories with 0.27% vacancy concentration \n with Mg doping', fontsize=25, x=0.5, y=0.68) 
(ax, ax2, ax3) = fig.subplots(1, 3)

ax.set_title('xy projection', size=20)
ax.set_xlabel('x', size=20)
ax.set_ylabel('y', size=20)
ax.set_xlim(-1, 23.505)
ax.set_ylim(-1, 23.505)
ax.set_aspect('equal', adjustable='box')

ax2.set_title('xz projection', size=20)
ax2.set_xlabel('x', size=20)
ax2.set_ylabel('z', size=20)
ax2.set_xlim(-1, 23.505)
ax2.set_ylim(-1, 23.505)
ax2.set_aspect('equal', adjustable='box')

ax3.set_title('yz projection', size=20)
ax3.set_xlabel('y', size=20)
ax3.set_ylabel('z', size=20)
ax3.set_xlim(-1, 23.505)
ax3.set_ylim(-1, 23.505)
ax3.set_aspect('equal', adjustable='box')

# Plot paths:
for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax2.plot(na_coords_x[n], na_coords_z[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax3.plot(na_coords_y[n], na_coords_z[n], color='orange', zorder=-1)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []
cl_coords2 = []
cl_coords3 = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords2.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords3.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p, q, r in zip(cl_coords, cl_coords2, cl_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add alkaline earth ion:
mg = [2.250500045010, 2.250500045010, 0]

xy = patches.Circle((mg[0], mg[1]), 0.5, facecolor='pink', edgecolor='black')
xz = patches.Circle((mg[0], mg[2]), 0.5, facecolor='pink', edgecolor='black')
yz = patches.Circle((mg[1], mg[2]), 0.5, facecolor='pink', edgecolor='black')

ax.add_patch(xy)
ax2.add_patch(xz)
ax3.add_patch(yz)

# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='pink', lw=4)]

fig.legend(custom_lines, ['Na', 'Cl', 'Mg'], loc='upper right', bbox_to_anchor=(0.905,0.68))

# Save figure:
fig.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/mg_traj_clear.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_ca.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_ca.txt') as file:
    content = file.readlines()
for line in content:
    if '2 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
        
# Create figure:
fig = plt.figure(figsize=(20,20))
fig.tight_layout()
fig.suptitle('Na migration trajectories with 0.27% vacancy concentration \n with Ca doping', fontsize=25, x=0.5, y=0.68) 
(ax, ax2, ax3) = fig.subplots(1, 3)

ax.set_title('xy projection', size=20)
ax.set_xlabel('x', size=20)
ax.set_ylabel('y', size=20)
ax.set_xlim(-1, 23.505)
ax.set_ylim(-1, 23.505)
ax.set_aspect('equal', adjustable='box')

ax2.set_title('xz projection', size=20)
ax2.set_xlabel('x', size=20)
ax2.set_ylabel('z', size=20)
ax2.set_xlim(-1, 23.505)
ax2.set_ylim(-1, 23.505)
ax2.set_aspect('equal', adjustable='box')

ax3.set_title('yz projection', size=20)
ax3.set_xlabel('y', size=20)
ax3.set_ylabel('z', size=20)
ax3.set_xlim(-1, 23.505)
ax3.set_ylim(-1, 23.505)
ax3.set_aspect('equal', adjustable='box')

# Plot paths:
for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax2.plot(na_coords_x[n], na_coords_z[n], color='orange', zorder=-1)

for n in range(0, na_atoms):
    ax3.plot(na_coords_y[n], na_coords_z[n], color='orange', zorder=-1)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []
cl_coords2 = []
cl_coords3 = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords2.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
        cl_coords3.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p, q, r in zip(cl_coords, cl_coords2, cl_coords3):
    ax.add_patch(p)
    ax2.add_patch(q)
    ax3.add_patch(r)
    
# Add alkaline earth ion:
mg = [2.250500045010, 2.250500045010, 0]

xy = patches.Circle((mg[0], mg[1]), 0.5, facecolor='purple', edgecolor='black')
xz = patches.Circle((mg[0], mg[2]), 0.5, facecolor='purple', edgecolor='black')
yz = patches.Circle((mg[1], mg[2]), 0.5, facecolor='purple', edgecolor='black')

ax.add_patch(xy)
ax2.add_patch(xz)
ax3.add_patch(yz)

# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='purple', lw=4)]

fig.legend(custom_lines, ['Na', 'Cl', 'Ca'], loc='upper right', bbox_to_anchor=(0.905,0.68))

# Save figure:
fig.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/ca_traj_clear.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if '1 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
 
# Plot paths:
fig, ax = plt.subplots()

for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

# Create figure:

plt.title('Undoped (0.27%)', fontsize=20) 
plt.xlabel('x', size=16)
plt.ylabel('y', size=16)
plt.xlim(-1, 23.505)
plt.ylim(-1, 23.505)
plt.gca().set_aspect('equal', adjustable='box')

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))

del cl_coords[0]
    
for p in cl_coords:
    ax.add_patch(p)
    
# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4)]

plt.legend(custom_lines, ['Na', 'O', 'Cl'], loc='upper right')

# Save figure:
plt.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/schottky_traj_single.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_mg.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_mg.txt') as file:
    content = file.readlines()
for line in content:
    if '2 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
 
# Plot paths:
fig, ax = plt.subplots()

for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

# Create figure:

plt.title('Mg doped (0.27%)', fontsize=20) 
plt.xlabel('x', size=16)
plt.ylabel('y', size=16)
plt.xlim(-1, 23.505)
plt.ylim(-1, 23.505)
plt.gca().set_aspect('equal', adjustable='box')

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p in cl_coords:
    ax.add_patch(p)
    
# Add alkaline earth ion:
mg = [2.250500045010, 2.250500045010, 0]

xy = patches.Circle((mg[0], mg[1]), 0.5, facecolor='pink', edgecolor='black')

ax.add_patch(xy)
    
# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='pink', lw=4)]

plt.legend(custom_lines, ['Na', 'O', 'Cl', 'Mg'], loc='upper right')

# Save figure:
plt.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/mg_traj_single.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_ca.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_ca.txt') as file:
    content = file.readlines()
for line in content:
    if '2 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))
 
# Plot paths:
fig, ax = plt.subplots()

for n in range(0, na_atoms):
    ax.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

# Create figure:

plt.title('Ca doped (0.27%)', fontsize=20) 
plt.xlabel('x', size=16)
plt.ylabel('y', size=16)
plt.xlim(-1, 23.505)
plt.ylim(-1, 23.505)
plt.gca().set_aspect('equal', adjustable='box')

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p in cl_coords:
    ax.add_patch(p)
    
# Add alkaline earth ion:
mg = [2.250500045010, 2.250500045010, 0]

xy = patches.Circle((mg[0], mg[1]), 0.5, facecolor='purple', edgecolor='black')

ax.add_patch(xy)
    
# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='purple', lw=4)]

plt.legend(custom_lines, ['Na', 'O', 'Cl', 'Ca'], loc='upper right')

# Save figure:
plt.savefig('/home/ben/Documents/lammps_calcs/5x5x5/graphs/ca_traj_single.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import numpy as np

# Set number of Na atoms, timesteps and extract lines with Na:
step_count = []
na = []

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('./outputs/na_traj_schottky.txt') as file:
    content = file.readlines()
for line in content:
    if '1 1.0' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

# Sort out coordinates by dimension:
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][3]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][4]))

na_coords_x_adj = []
na_coords_y_adj = []
        
for i in na_coords_x:
    coords = []
    for n in i:
        if n <= 15.7535:
            a = n + 15.7535
        else:
            a = n - 15.7535
        coords.append(a)
    na_coords_x_adj.append(coords)
        
for i in na_coords_y:
    coords = []
    for n in i:
        if n <= 15.7535:
            a = n + 15.7535
        else:
            a = n - 15.7535
        coords.append(a)
    na_coords_y_adj.append(coords)
        
# Plot paths:
fig, ax = plt.subplots()

for n in range(0, na_atoms):
    ax.plot(na_coords_x_adj[n], na_coords_y_adj[n], color='orange', zorder=-1)

# Create figure:

plt.title('Undoped (0.27%)', fontsize=20) 
plt.xlabel('x', size=16)
plt.ylabel('y', size=16)
plt.xlim(-1, 23.505)
plt.ylim(-1, 23.505)
plt.gca().set_aspect('equal', adjustable='box')

# Add oxide ions:
o_x = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_y = [2.2505, 6.7515, 11.2525, 15.7535, 20.2545]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)
    
# Add chloride ions:
cl_x = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_y = [0, 4.501, 9.002, 13.503, 18.004, 22.505]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))

del cl_coords[0]
    
for p in cl_coords:
    ax.add_patch(p)
    
# Add legend:
custom_lines = [Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='green', lw=4)]

plt.legend(custom_lines, ['Na', 'O', 'Cl'], loc='upper right')

# Save figure:
plt.savefig('/home/ben/Documents/na3ocl project/lammps_calcs/2ns/5x5x5/graphs/schottky_traj_centred.jpg', bbox_inches='tight', dpi=500)

# %%
na_coords_y_adj
# Out:
# [[18.05514],
#  [20.28492],
#  [18.126070000000002],
#  [17.910690000000002],
#  [17.965400000000002],
#  [20.387700000000002],
#  [22.70473],
#  [22.85442],
#  [22.28903],
#  [22.38923],
#  [25.006120000000003],
#  [29.0325],
#  [26.9745],
#  [26.704500000000003],
#  [27.1264],
#  [31.3857],
#  [1.6898],
#  [31.0451],
#  [0.24799999999999933],
#  [31.227899999999998],
#  [0.2727999999999984],
#  [5.2563999999999975],
#  [4.7173],
#  [4.754699999999998],
#  [4.117900000000001],
#  [18.23828],
#  [18.37368],
#  [17.83748],
#  [18.34842],
#  [17.89835],
#  [22.69179],
#  [22.4664],
#  [22.93365],
#  [22.63037],
#  [20.31335],
#  [27.2419],
#  [26.737000000000002],
#  [27.1117],
#  [26.818],
#  [26.8076],
#  [31.5049],
#  [0.31269999999999776],
#  [0.30410000000000004],
#  [28.983600000000003],
#  [0.6921999999999979],
#  [4.577299999999999],
#  [4.155599999999998],
#  [4.6609],
#  [15.7457233046],
#  [4.5318999999999985],
#  [18.388820000000003],
#  [17.792550000000002],
#  [17.922430000000002],
#  [18.0527],
#  [18.417450000000002],
#  [22.850900000000003],
#  [22.76081],
#  [22.48262],
#  [22.81944],
#  [22.266370000000002],
#  [24.78241],
#  [27.029200000000003],
#  [27.3088],
#  [26.578000000000003],
#  [27.280900000000003],
#  [31.3095],
#  [0.713099999999999],
#  [31.0528],
#  [31.1979],
#  [31.360500000000002],
#  [4.737299999999999],
#  [4.532099999999998],
#  [15.894068],
#  [2.2499999999999982],
#  [4.706999999999999],
#  [17.88313],
#  [18.35705],
#  [18.32687],
#  [17.80581],
#  [18.638170000000002],
#  [22.74043],
#  [22.54014],
#  [22.14702],
#  [22.67142],
#  [21.98132],
#  [27.099899999999998],
#  [27.1044],
#  [27.1996],
#  [27.0956],
#  [27.337600000000002],
#  [0.07019999999999982],
#  [31.4058],
#  [31.448300000000003],
#  [0.525999999999998],
#  [0.22619999999999862],
#  [4.818],
#  [4.611299999999998],
#  [5.326499999999998],
#  [4.481299999999999],
#  [4.2829999999999995],
#  [17.896900000000002],
#  [18.21665],
#  [17.718890000000002],
#  [17.97201],
#  [17.38506],
#  [22.988570000000003],
#  [22.31411],
#  [22.439420000000002],
#  [22.462310000000002],
#  [22.36553],
#  [26.7384],
#  [27.0344],
#  [26.9903],
#  [26.9955],
#  [27.0826],
#  [31.209600000000002],
#  [0.07819999999999894],
#  [0.2527999999999988],
#  [0.27800000000000047],
#  [31.2805],
#  [2.2493999999999996],
#  [4.752899999999999],
#  [4.088800000000001],
#  [4.210399999999998],
#  [4.1119],
#  [17.78198],
#  [6.888524695399999],
#  [6.691799999999999],
#  [6.600399999999999],
#  [4.275899999999998],
#  [23.04384],
#  [20.49592],
#  [20.17026],
#  [20.06845],
#  [22.68042],
#  [26.9477],
#  [24.88496],
#  [24.77192],
#  [24.446910000000003],
#  [24.7952],
#  [29.514200000000002],
#  [31.3378],
#  [29.283],
#  [29.463900000000002],
#  [27.1723],
#  [4.6333],
#  [4.6517],
#  [2.1038999999999977],
#  [5.134399999999998],
#  [4.110100000000001],
#  [15.915885000000001],
#  [6.7504683954],
#  [4.824199999999999],
#  [4.6485],
#  [15.928468],
#  [20.57075],
#  [20.31418],
#  [20.37722],
#  [18.0283],
#  [20.23158],
#  [24.91981],
#  [24.51318],
#  [24.90621],
#  [24.81531],
#  [22.33438],
#  [29.5079],
#  [29.400199999999998],
#  [29.5317],
#  [31.063000000000002],
#  [29.1806],
#  [2.3980999999999977],
#  [2.5801999999999996],
#  [2.4136000000000006],
#  [4.5755],
#  [2.033900000000001],
#  [15.979031],
#  [15.990952],
#  [17.53516],
#  [15.802400400000002],
#  [16.210625],
#  [20.40522],
#  [20.229680000000002],
#  [20.08611],
#  [20.15439],
#  [20.67146],
#  [22.18616],
#  [24.69236],
#  [24.89142],
#  [24.683880000000002],
#  [27.029200000000003],
#  [29.439],
#  [29.1917],
#  [29.4214],
#  [29.2758],
#  [29.392200000000003],
#  [2.3072999999999997],
#  [2.486600000000001],
#  [4.580299999999999],
#  [2.353799999999998],
#  [31.203400000000002],
#  [7.085364695400001],
#  [17.84825],
#  [16.016477000000002],
#  [15.710323304600001],
#  [15.876294000000001],
#  [20.01953],
#  [18.499390000000002],
#  [20.24943],
#  [20.23861],
#  [20.19642],
#  [24.945880000000002],
#  [24.69522],
#  [24.803710000000002],
#  [24.99519],
#  [24.77016],
#  [29.54],
#  [29.3236],
#  [29.6558],
#  [29.1832],
#  [27.086],
#  [2.4884000000000004],
#  [2.5785],
#  [2.6836],
#  [2.2361999999999984],
#  [0.12420000000000009],
#  [14.098323304600001],
#  [15.814354100000001],
#  [15.859222],
#  [6.2921],
#  [6.660400000000001],
#  [20.26519],
#  [20.09359],
#  [20.213720000000002],
#  [20.351280000000003],
#  [20.038220000000003],
#  [24.83891],
#  [24.657760000000003],
#  [24.9052],
#  [24.7365],
#  [24.52315],
#  [28.961100000000002],
#  [29.2554],
#  [29.428600000000003],
#  [29.2646],
#  [28.9156],
#  [4.2143],
#  [2.2486999999999977],
#  [0.19459999999999944],
#  [1.9859999999999989],
#  [4.7509999999999994],
#  [18.18261],
#  [18.25542],
#  [18.07902],
#  [17.78141],
#  [17.82076],
#  [22.06274],
#  [22.657980000000002],
#  [22.78712],
#  [22.39026],
#  [22.25262],
#  [26.8022],
#  [26.7406],
#  [27.3784],
#  [26.7892],
#  [26.8199],
#  [0.4228000000000005],
#  [31.157],
#  [31.402900000000002],
#  [29.0213],
#  [2.2681999999999984],
#  [2.265399999999998],
#  [4.5638999999999985],
#  [2.202799999999998],
#  [4.292799999999998],
#  [2.079299999999998],
#  [18.55948],
#  [18.25718],
#  [17.80956],
#  [17.96603],
#  [15.772723304600001],
#  [22.523880000000002],
#  [22.566860000000002],
#  [22.69284],
#  [22.31974],
#  [24.8744],
#  [26.9306],
#  [27.6325],
#  [27.4616],
#  [26.5428],
#  [27.1203],
#  [0.13289999999999935],
#  [31.189100000000003],
#  [0.25329999999999764],
#  [31.3035],
#  [0.14139999999999908],
#  [6.722399999999999],
#  [4.581200000000001],
#  [4.1271],
#  [2.335700000000001],
#  [4.5246999999999975],
#  [18.220840000000003],
#  [18.28588],
#  [17.95857],
#  [16.07216],
#  [18.464550000000003],
#  [22.60875],
#  [22.45466],
#  [22.25065],
#  [22.52531],
#  [22.47513],
#  [27.216900000000003],
#  [27.285800000000002],
#  [27.8709],
#  [26.7431],
#  [26.8887],
#  [0.5638999999999985],
#  [0.3620000000000001],
#  [0.2483999999999984],
#  [2.527099999999999],
#  [31.4521],
#  [4.7813],
#  [4.595699999999999],
#  [4.5678],
#  [4.656799999999999],
#  [4.321299999999999],
#  [18.22741],
#  [15.973993],
#  [17.69421],
#  [17.89355],
#  [22.30191],
#  [20.12164],
#  [21.9441],
#  [22.26236],
#  [22.942520000000002],
#  [27.0955],
#  [26.5271],
#  [27.0364],
#  [27.1189],
#  [24.87528],
#  [31.4902],
#  [0.07620000000000005],
#  [0.31049999999999933],
#  [31.342],
#  [0.1280000000000001],
#  [4.538500000000001],
#  [4.732200000000001],
#  [4.1938999999999975],
#  [4.7173],
#  [2.2356999999999996],
#  [15.968331000000001],
#  [17.98031],
#  [18.1246],
#  [17.868660000000002],
#  [18.03717],
#  [22.60258],
#  [22.36422],
#  [22.58021],
#  [22.62219],
#  [22.40583],
#  [26.976300000000002],
#  [26.612000000000002],
#  [27.163800000000002],
#  [26.742800000000003],
#  [26.643],
#  [0.16139999999999866],
#  [0.33179999999999943],
#  [31.2251],
#  [31.1614],
#  [29.4585],
#  [2.3038000000000007],
#  [4.754099999999999],
#  [4.643099999999999],
#  [4.307899999999998],
#  [4.233600000000001]]
