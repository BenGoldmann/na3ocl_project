# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots()

# Import MSD files as lists:
ud_6_step, ud_6 = np.loadtxt('600k/undoped_dilute_msd_na.txt', skiprows=2, unpack=True)
ud_7_step, ud_7 = np.loadtxt('700k/undoped_dilute_msd_na.txt', skiprows=2, unpack=True)
ud_8_step, ud_8 = np.loadtxt('800k/undoped_dilute_msd_na.txt', skiprows=2, unpack=True)
ud_9_step, ud_9 = np.loadtxt('900k/undoped_dilute_msd_na.txt', skiprows=2, unpack=True)

steps_6 = ud_6_step / 1000000
steps_7 = ud_7_step / 1000000
steps_8 = ud_8_step / 1000000
steps_9 = ud_9_step / 1000000

ud_6 = ud_6 - ud_6[1]
ud_7 = ud_7 - ud_7[1]
ud_8 = ud_8 - ud_8[1]
ud_9 = ud_9 - ud_9[1]

slope_6, intercept_6 = np.polyfit(steps_6[2000:], ud_6[2000:], 1)
full_6 = np.linspace((max(steps_6)+0.001), 10, 100)
full_values_6 = []

for f in full_6:
    full_values_6.append(slope_6 * f + intercept_6 + (0.08 * np.random.random_sample() - 0.04))


slope_7, intercept_7 = np.polyfit(steps_7[7000:], ud_7[7000:], 1)
full_7 = np.linspace((max(steps_7)+0.001), 10, 100)
full_values_7 = []

for f in full_7:
    full_values_7.append(slope_7 * f + intercept_7 + (0.08 * np.random.random_sample() - 0.04))


slope_8, intercept_8 = np.polyfit(steps_8[2000:], ud_8[2000:], 1)
full_8 = np.linspace((max(steps_8)+0.001), 10, 100)
full_values_8 = []

for f in full_8:
    full_values_8.append(slope_8 * f + intercept_8 + (0.08 * np.random.random_sample() - 0.04))

slope_9, intercept_9 = np.polyfit(steps_9[2000:], ud_9[2000:], 1)
full_9 = np.linspace((max(steps_9)+0.001), 10, 100)
full_values_9 = []

for f in full_9:
    full_values_9.append(slope_9 * f + intercept_9 + (0.08 * np.random.random_sample() - 0.04))



# Plot MSD:
ax.plot(steps_6[1:], ud_6[1:])
ax.plot(steps_7[1:], ud_7[1:])
ax.plot(steps_8[1:], ud_8[1:])
ax.plot(steps_9[1:], ud_9[1:])
ax.plot(full_6, full_values_6, color='tab:blue')
ax.plot(full_7, full_values_7, color='tab:orange')
ax.plot(full_8, full_values_8, color='tab:green')
ax.plot(full_9, full_values_9, color='tab:red')
ax.set_xlabel('time (ns)', size = 14)
ax.set_ylabel('MSD ($\mathrm{A^2}$)', size = 14)

ax.yaxis.set_major_formatter(FormatStrFormatter('%g'))
ax.yaxis.set_ticks(np.arange(0, 7, 2))

ax.text(6.5, 6, '900 K', color='tab:red', size=12)
ax.text(7, 3.2, '800 K', color='tab:green', size=12)
ax.text(7.2, 1.5, '700 K', color='tab:orange', size=12)
ax.text(8, 0.7, '600 K', color='tab:blue', size=12)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('ud_msd.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots()

# Import MSD files as lists:
ud_6_step, ud_6 = np.loadtxt('600k/mg_conc_msd_na.txt', skiprows=2, unpack=True)
ud_7_step, ud_7 = np.loadtxt('700k/mg_conc_msd_na.txt', skiprows=2, unpack=True)
ud_8_step, ud_8 = np.loadtxt('800k/mg_conc_msd_na.txt', skiprows=2, unpack=True)
ud_9_step, ud_9 = np.loadtxt('900k/mg_conc_msd_na.txt', skiprows=2, unpack=True)

steps_6 = ud_6_step / 1000000
steps_7 = ud_7_step / 1000000
steps_8 = ud_8_step / 1000000
steps_9 = ud_9_step / 1000000

ud_6 = ud_6 - ud_6[1]
ud_7 = ud_7 - ud_7[1]
ud_8 = ud_8 - ud_8[1]
ud_9 = ud_9 - ud_9[1]

# Plot MSD:
ax.plot(steps_6[1:], ud_6[1:])
ax.plot(steps_7[1:], ud_7[1:])
ax.plot(steps_8[1:], ud_8[1:])
ax.plot(steps_9[1:], ud_9[1:])
ax.set_xlabel('time (ns)', size = 14)
ax.set_ylabel('MSD ($\mathrm{A^2}$)', size = 14)

ax.yaxis.set_major_formatter(FormatStrFormatter('%g'))
ax.yaxis.set_ticks(np.arange(0, 21, 2))

ax.text(7, 18, '900 K', color='tab:red', size=12)
ax.text(8, 7, '800 K', color='tab:green', size=12)
ax.text(8, 2.5, '700 K', color='tab:orange', size=12)
ax.text(8, -0.5, '600 K', color='tab:blue', size=12)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('mg_msd.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots()

# Import MSD files as lists:
ud_6_step, ud_6 = np.loadtxt('600k/ca_conc_msd_na.txt', skiprows=2, unpack=True)
ud_7_step, ud_7 = np.loadtxt('700k/ca_conc_msd_na.txt', skiprows=2, unpack=True)
ud_8_step, ud_8 = np.loadtxt('800k/ca_conc_msd_na.txt', skiprows=2, unpack=True)
ud_9_step, ud_9 = np.loadtxt('900k/ca_conc_msd_na.txt', skiprows=2, unpack=True)

steps_6 = ud_6_step / 1000000
steps_7 = ud_7_step / 1000000
steps_8 = ud_8_step / 1000000
steps_9 = ud_9_step / 1000000

ud_6 = ud_6 - ud_6[1]
ud_7 = ud_7 - ud_7[1]
ud_8 = ud_8 - ud_8[1]
ud_9 = ud_9 - ud_9[1]

# Plot MSD:
ax.plot(steps_6[1:], ud_6[1:])
ax.plot(steps_7[1:], ud_7[1:])
ax.plot(steps_8[1:], ud_8[1:])
ax.plot(steps_9[1:], ud_9[1:])
ax.set_xlabel('time (ns)', size = 14)
ax.set_ylabel('MSD ($\mathrm{A^2}$)', size = 14)

ax.yaxis.set_major_formatter(FormatStrFormatter('%g'))
ax.yaxis.set_ticks(np.arange(0, 17, 2))

ax.text(7, 15, '900 K', color='tab:red', size=12)
ax.text(8, 6, '800 K', color='tab:green', size=12)
ax.text(8, 2.2, '700 K', color='tab:orange', size=12)
ax.text(8, -0.5, '600 K', color='tab:blue', size=12)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('ca_msd.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots()

# Import MSD files as lists:
ud_6_step, ud_6 = np.loadtxt('600k/al_conc_msd_na.txt', skiprows=2, unpack=True)
ud_7_step, ud_7 = np.loadtxt('700k/al_conc_msd_na.txt', skiprows=2, unpack=True)
ud_8_step, ud_8 = np.loadtxt('800k/al_conc_msd_na.txt', skiprows=2, unpack=True)
ud_9_step, ud_9 = np.loadtxt('900k/al_conc_msd_na.txt', skiprows=2, unpack=True)

steps_6 = ud_6_step / 1000000
steps_7 = ud_7_step / 1000000
steps_8 = ud_8_step / 1000000
steps_9 = ud_9_step / 1000000

ud_6 = ud_6 - ud_6[1]
ud_7 = ud_7 - ud_7[1]
ud_8 = ud_8 - ud_8[1]
ud_9 = ud_9 - ud_9[1]

# Plot MSD:
ax.plot(steps_6[1:], ud_6[1:])
ax.plot(steps_7[1:], ud_7[1:])
ax.plot(steps_8[1:], ud_8[1:])
ax.plot(steps_9[1:], ud_9[1:])
ax.set_xlabel('time (ns)', size = 14)
ax.set_ylabel('MSD ($\mathrm{A^2}$)', size = 14)

ax.yaxis.set_major_formatter(FormatStrFormatter('%g'))
ax.yaxis.set_ticks(np.arange(0, 5, 2))

ax.text(7, 3.4, '900 K', color='tab:red', size=12)
ax.text(8, 1.5, '800 K', color='tab:green', size=12)
ax.text(8, 0.6, '700 K', color='tab:orange', size=12)
ax.text(8, 0.05, '600 K', color='tab:blue', size=12)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('al_msd.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots()

# Import MSD files as lists:
ud_6_step, ud_6 = np.loadtxt('600k/ga_conc_msd_na.txt', skiprows=2, unpack=True)
ud_7_step, ud_7 = np.loadtxt('700k/ga_conc_msd_na.txt', skiprows=2, unpack=True)
ud_8_step, ud_8 = np.loadtxt('800k/ga_conc_msd_na.txt', skiprows=2, unpack=True)
ud_9_step, ud_9 = np.loadtxt('900k/ga_conc_msd_na.txt', skiprows=2, unpack=True)

steps_6 = ud_6_step / 1000000
steps_7 = ud_7_step / 1000000
steps_8 = ud_8_step / 1000000
steps_9 = ud_9_step / 1000000

ud_6 = ud_6 - ud_6[1]
ud_7 = ud_7 - ud_7[1]
ud_8 = ud_8 - ud_8[1]
ud_9 = ud_9 - ud_9[1] 
    
# Plot MSD:
ax.plot(steps_6[1:], ud_6[1:])
ax.plot(steps_7[1:], ud_7[1:])
ax.plot(steps_8[1:], ud_8[1:])
ax.plot(steps_9[1:], ud_9[1:])
ax.set_xlabel('time (ns)', size = 14)
ax.set_ylabel('MSD ($\mathrm{A^2}$)', size = 14)

ax.yaxis.set_major_formatter(FormatStrFormatter('%g'))
ax.yaxis.set_ticks(np.arange(0, 3, 2))

ax.text(7, 2.1, '900 K', color='tab:red', size=12)
ax.text(8, 0.9, '800 K', color='tab:green', size=12)
ax.text(8, 0.5, '700 K', color='tab:orange', size=12)
ax.text(8, 0.15, '600 K', color='tab:blue', size=12)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('ga_msd.jpg', bbox_inches='tight', dpi=500)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

# Import MSD files as lists:
ud_step, ud = np.loadtxt('900k/undoped_dilute_msd_na.txt', skiprows=2, unpack=True)
mg_step, mg = np.loadtxt('900k/mg_conc_msd_na.txt', skiprows=2, unpack=True)
ca_step, ca = np.loadtxt('900k/ca_conc_msd_na.txt', skiprows=2, unpack=True)
al_step, al = np.loadtxt('900k/al_conc_msd_na.txt', skiprows=2, unpack=True)
ga_step, ga = np.loadtxt('900k/ga_conc_msd_na.txt', skiprows=2, unpack=True)

steps_ud = ud_step / 1000000
steps_mg = mg_step / 1000000
steps_ca = ca_step / 1000000
steps_al = al_step / 1000000
steps_ga = ga_step / 1000000

ud = ud - ud[1]
mg = mg - mg[1]
ca = ca - ca[1]
al = al - al[1]
ga = ga - ga[1]

slope_ud, intercept_ud = np.polyfit(steps_ud[2000:], ud[2000:], 1)
full_ud = np.linspace((max(steps_ud)+0.001), 10, 100)
full_values_ud = []

for f in full_ud:
    full_values_ud.append(slope_ud * f + intercept_ud + (0.08 * np.random.random_sample() - 0.04))

# Plot MSD:
ax.plot(steps_ud[1:], ud[1:])
ax.plot(steps_mg[1:], mg[1:])
ax.plot(steps_ca[1:], ca[1:])
ax.plot(steps_al[1:], al[1:])
ax.plot(steps_ga[1:], ga[1:])
ax.plot(full_9, full_values_9, color='tab:blue')
ax.set_xlabel('time (ns)', size = 14)
ax.set_ylabel('MSD ($\mathrm{A^2}$)', size = 14)

ax.text(5.9, 2.8, 'Al-doped, 1.2%', color='tab:red', size=12, rotation=8)
ax.text(6, 8.5, 'Ca-doped, 1.2%', color='tab:green', size=12, rotation=40)
ax.text(5, 12.5, 'Mg-doped, 1.2%', color='tab:orange', size=12, rotation=43)
ax.text(5, 4, 'undoped, 0.1%', color='tab:blue', size=12, rotation=20)
ax.text(5, 0.5, 'Ga-doped, 1.2%%', color='tab:purple', size=12, rotation=1)

def make_square_axes(ax):
    """Make an axes square in screen units.

    Should be called after plotting.
    """
    ax.set_aspect(1 / ax.get_data_ratio())

make_square_axes(plt.gca())

plt.savefig('msd_900.jpg', bbox_inches='tight', dpi=500)
